# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import sklearn

# %% [markdown]
# Q2) read the csv file and store it in a dataframe

# %%
data = pd.read_csv("USA_Housing.csv")
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# Q3) check out the top 5 data in your dataframe using the head() function of pandas

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# Q4) check out the bottom 5 data in your dataframe using tail() function

# %%
data.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population        Price  \
# 4995                          3.46      22837.36103  1060193.786
# 4996                          4.02      25616.11549  1482617.729
# 4997                          2.13      33266.14549  1030729.583
# 4998                          5.44      42625.62016  1198656.872
# 4999                          4.07      46501.28380  1298950.480
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %% [markdown]
# Q5) check out the info of your dataframe using the info function of pandas

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %% [markdown]
# Q6) check out the summary of dataframe using describe method of pandas

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# Q7) Use the pairplot method of seaborn and check out the graph

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# Q8) Plot the graph for Price vs Area

# %%
sns.jointplot(x = 'Price', y = 'Avg. Area Number of Bedrooms', data = data, kind = "hex")
plt.show()

# %% [markdown]
# Q9) Plot the graph for House Age vs Price

# %%
sns.jointplot(x = 'Avg. Area House Age', y = 'Price', data = data, kind = "reg")
plt.show()

# %% [markdown]
# Q10) Plot the graph for population vs income.

# %%
sns.jointplot(x = 'Area Population', y = 'Avg. Area Income', data = data, kind = "hex")
plt.show()

# %% [markdown]
# Q11) Plot the graph for Area vs Rooms

# %%
sns.jointplot(x = 'Avg. Area House Age', y = 'Avg. Area Number of Rooms', data = data)
plt.show()

# %% [markdown]
# Q12) Use distplot on price column and observe the distribution

# %%
sns.distplot(data['Price'])
plt.show()

# %% [markdown]
# Q13) Use distplot on house age column and observe the distribution

# %%
sns.distplot(data['Avg. Area House Age'], kde = False)
plt.show()

# %% [markdown]
# Q14) Use distplot on population column and observe the distribution

# %%
sns.distplot(data['Area Population'], bins = 20)
plt.show()

# %% [markdown]
# Q 15)

# %%
X = data[["Avg. Area Income", "Avg. Area House Age", "Avg. Area Number of Rooms", 
                 "Avg. Area Number of Bedrooms", "Area Population"]]

y = data["Price"]

# %% [markdown]
# Q 16)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 101)

# %% [markdown]
# Q 17)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Q 18)

# %%
print(lm.intercept_)
# Out:
# -2640159.796813771

# %%
coeff_df = pd.DataFrame(lm.coef_, X.columns, columns = ["Coefficient"])
coeff_df
# Out:
#                                 Coefficient
# Avg. Area Income                  21.528276
# Avg. Area House Age           164883.282027
# Avg. Area Number of Rooms     122368.678023
# Avg. Area Number of Bedrooms    2233.801864
# Area Population                   15.150420
